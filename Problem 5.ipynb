# %% [markdown]
# Design & develop a web application to maintain records of students.
#
# The single the record shall contain the following information:
#
# | Name | Roll number | Age | Gender |
#
#
#
# The application should have the ability to INSERT, DELETE, UPDATE & SEARCH records.
#
# Please Note: this application should not use any DATABASE.

# %%
#create class Student

class Student:
    # Constructor
    def __init__(self, name, rollno, age, gender):
        self.name = name
        self.rollno = rollno
        self.age = age
        self.gender = gender
        
    # Function to create and insert new student details
    def insert(self, Name, Rollno, Age, Gender):
        # used init(input()) method to take input from user
        ob = Student(Name, Rollno, Age, Gender)
        ls.append(ob)
        
    # Function to displayh student details
    def display(self, ob):
        print("Name : ", ob.name)
        print("Roll Number : ", ob.rollno)
        print("Age : ", ob.age)
        print("Gender : ", ob.gender)
        print("\n")
        
    # Function to search
    def search(self, rn):
        for i in range (ls.__len__()):
            if(ls[i].rollno == rn):
                return i
    
    # Function to Delete
    def delete(self, rn):
        i = obj.search(rn)
        del ls[i]
        
    # Function to Update
    def update(self, rn, No, newname, newage, newgender):
        i = obj.search(rn)
        roll = No
        ls[i].rollno = roll;
        ls[i].name = newname;
        ls[i].age = newage;
        ls[i].gender = newgender;
        
# create a list to add students
ls = []
# an obj of Student Class
obj = Student('',0,0,'')

while True:
    print('''
        \n1.Insert Student details\n2.Display Student Details
3.Search Details of a Student\n4.Delete Details of Student
5.Update Student Details\n6.Exit
        ''')


    try: #Using Exceptions For Validation
        ch = int(input("Please Select An Above Option: ")) #Will Take Input From User
    
    except ValueError:
        exit("\nHy! That's Not A Number") #Error Message
    
    else:
        print("\n")    
        
    if(ch == 1):
        print("Enter student details : ")
        name = input("Name : ")    
        rollno = int(input("ROll Number : "))
        age = int(input("Age : "))
        gender = input("Gender : ")

        obj.insert(name, rollno, age, gender)
         
    elif(ch == 2):
        print("\n")
        print("\nList of Students\n")
        for i in range(ls.__len__()):    
            obj.display(ls[i])
             
    elif(ch == 3):
        rollNo = int(input("Enter  Roll Number: ")) 
        s = obj.search(rollNo)
        print(s)
        obj.display(ls[s])
         
    elif(ch == 4):
        rollNo = int(input("Enter  Roll Number: "))
        obj.delete(rollNo)
        print(ls.__len__())
        print("List after deletion")
        for i in range(ls.__len__()):    
            obj.display(ls[i])
             
    elif(ch == 5):
        rollNo = int(input("Enter  Roll Number: "))
        
        newName = input("Enter New Name: ")
        newRollNo = int(input("Enter New Roll Number: "))
        newAge = int(input("Enter Age: "))
        newGender = input("Enter New Gender: ")
        
        obj.update(rollNo, newName, newRollNo, newAge, newGender)
        print(ls.__len__())
        print("List after updation")
        for i in range(ls.__len__()):    
            obj.display(ls[i])

    elif(ch < 1 or ch > 6):
        print("Please Enter Valid Choice")
        
    
    else:
        break
# Out:
#
# 1.Insert Student details
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete Details of Student
# 5.Update Student Details
# 6.Exit
#
# Please Select An Above Option: 1
#
#
# Enter student details :
# Name : Nirav
# ROll Number : 10
# Age : 26
# Gender : Male
#
#
# 1.Insert Student details
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete Details of Student
# 5.Update Student Details
# 6.Exit
#
# Please Select An Above Option: 6
